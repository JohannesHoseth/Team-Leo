# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import requests
import scraping_class

# %%
#Logging
logfile = 'log.csv'## name your log file.
connector = scraping_class.Connector(logfile)

# %%
url = 'https://www.imdb.com/title/tt5580390/keywords?ref_=tt_stry_kw'
response,call_id = connector.get(url, 'keywords')
if response.ok:
    d = response.text

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(d, 'lxml')

# %%
keywords = soup.find_all('td', attrs={'soda sodavote'})

# %%
[keywords['data-item-keyword='] for keywords in links]
#ahh, this retrieves all of them because they have data-item.. in them

keywords
# Out:
# [<td class="soda sodavote" data-item-keyword="underwater scene" data-item-votes="0">
#  <div class="sodatext">
#  <a href="/search/keyword?keywords=underwater-scene">underwater scene</a>
#  </div>
#  <div class="did-you-know-actions">
#  <div class="interesting-count-text">
#  <a href="?item=kw0014781"> 9 of 9 found this relevant
#  </a> </div>
#  <span class="interesting-cast-vote" data-item-id="kw0014781" data-item-type="keyword">
#  <span>Relevant?</span>
#  <button class="cast-vote" value="up">Yes</button>
#  <button class="cast-vote" value="down">No</button>
#  </span>
#  </div>
#  </td>,
#  <td class="soda sodavote" data-item-keyword="mute woman" data-item-votes="1">
#  <div class="sodatext">
#  <a href="/search/keyword?keywords=mute-woman">mute woman</a>
#  </div>
#  <div class="did-you-know-actions">
#  <div class="interesting-count-text">
#  <a href="?item=kw0096814"> 13 of 14 found this relevant
#  </a> </div>
# ...

# %%
links = []

for i in keywords:
    
    link = str(i).split('data-item-keyword="')[1]
    
    link = link.split('"')[0]
    print(link)
    links.append(link)
# Out:
# underwater scene
# mute woman
# creature
# interspecies romance
# sign language
# fish man
# rescue
# female protagonist
# baltimore maryland
# 1960s
# aquatic humanoid
# mute
# water
# interspecies sex
# friendship
# laboratory
# lab
# egg
# female masturbation
# the color green
# escape
# scientist
# gay crush
# masturbating in a bathtub
# reference to vladimir lenin
# movie theater
# vivisection
# commercial artist
# year 1962
# space race
# soviet union
# captive
# military
# female nudity
# rain
# loneliness
# cruelty
# cold war
# topless female nudity
# female rear nudity
# female full frontal nudity
# interracial friendship
# pubic hair
# masturbation
# cleaning
# severed finger
# eating a cat
# title at the end
# cleaning crew
# homosexual
# male rear nudity
# black and white sequence
# security guard
# salt
# healing power
# pay phone
# racism
# reference to samson and delilah
# cleaning lady
# torture
# drawing
# watching tv
# dancing
# toupee
# musical number
# ...

# %%
keywords = pd.DataFrame(links)

keywords.head(3)
# Out:
#                   0
# 0  underwater scene
# 1        mute woman
# 2          creature

# %%
MPAA = soup.find_all('td')

# %%
MPAA
# Out:
# []
